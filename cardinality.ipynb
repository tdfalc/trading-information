# %%
import numpy as np
import matplotlib.pyplot as plt

# %config InlineBackend.figure_format = 'svg'


N = 1000

types = np.linspace(0, 1, N)
allocations = np.linspace(-1, 1, N)
threshold = 500

# %%
print(np.sum(allocations))
# Out:
# 0.0

# %%
fig, ax = plt.subplots()
ax.plot(types, allocations)
ax.axhline(y=0, color="k")

# %%
from math import comb
comb(4, 1)
# Out:
# 4

# %%
N = 1000
M = 4000

# %%
# Out:
# -3000
